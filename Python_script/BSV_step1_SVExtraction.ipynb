# %% [markdown]
# ### This notebook is for sub-volume extraction and radiomics calculation
# ### Author: Zhenwei Shi, Tianchen Luo, Xiaomei Huang,Zhihe Zhao

# %%
import os
import SimpleITK as sitk
import pandas as pd
import glob

import cv2
import numpy as np
import matplotlib.pyplot as plt
from skimage import measure, color
import skimage.morphology as morphology

from skimage.segmentation import mark_boundaries as mark_boundaries
from skimage.segmentation import slic as slic

import shutil

# %%
def SV_split(volume, mask, out_dir):

    mask_array = sitk.GetArrayFromImage(sitk.ReadImage(mask))
    _, num = measure.label(mask_array, connectivity=3, return_num=True) # meature label connected regions

    for i in range(1, num + 1):
        section_volume = sitk.GetArrayFromImage(sitk.ReadImage(volume))
        section_mask = sitk.GetArrayFromImage(sitk.ReadImage(mask))

        section_mask[section_mask != i] = 0 # split sv mask
        section_mask[section_mask == i] = 1 # split sv mask

        # ----- for SV mask split ------
        # print(mask.split('/')[-1].split('.')[-3]))
        svsplit_path = os.path.join(out_dir,'SVmask',mask.split('/')[-1].split('.')[-3].split('_')[-2]) # sv path per patient
        
        if not os.path.exists(svsplit_path):
            os.makedirs(svsplit_path)        
            
        sitk.WriteImage(sitk.GetImageFromArray(section_mask), # save sv mask separately
                os.path.join(svsplit_path, mask.split('/')[-1].split('.')[-3]) + str(i)+'.nii.gz')

        # ----- for SV volume split ------
        # print(volume.split('/')[-1].split('.')[-3])
    
        # # section_volume[section_mask == 0] = 0
        # sitk.WriteImage(sitk.GetImageFromArray(section_volume), # save sv mask separately
        #         os.path.join(svsplit_path, 'SVvolume', volume.split('/')[-1].split('.')[-3])+'_SVvolume_'+ str(i)+'.nii.gz')

def check_dataset(list_volume, list_mask):
    if len(list_volume) != len(list_mask):
        raise ValueError('There exists a mismatch between two datasets.')

def mac_os_listdir(path):
    files = os.listdir(path)
    if '.DS_Store' in files:
        files.remove('.DS_Store')
        files.sort()
    return files

def get_file_num(path):
    files_num = []
    files = os.listdir(path)
    for file in files:
        if file !='.DS_Store':
            # print(file)
            num = ""
            for c in file:
                if c.isdigit():
                    num = num + c
            # print("Extracted numbers from the list : " + num)
            files_num.append(num)
    return files_num

def supervoxel(volume_list,mask_list,n_segment,supervoxel_path,center):
    print('Start super voxel processing ...')
    if not os.path.exists(supervoxel_path):
        os.makedirs(supervoxel_path)
    
    if not os.path.exists(os.path.join(supervoxel_path,center)):
        os.makedirs(os.path.join(supervoxel_path,center))

    for volume_path, mask_path in zip(volume_list, mask_list):
        
        img = sitk.GetArrayFromImage(sitk.ReadImage(volume_path))
        mask = sitk.GetArrayFromImage(sitk.ReadImage(mask_path))
        img_normalized = cv2.normalize(img, None, alpha=0, beta=1, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_32F)
        tmp_mask = morphology.opening(mask, morphology.ball(1))

        try:
            slic_mask = slic(img_normalized, n_segment, compactness=10, mask=tmp_mask, start_label=1,
                             channel_axis=None)
        except:
            print('something wrong, SV computation failed !!!')

        mask_itk = sitk.GetImageFromArray(np.uint16(slic_mask))

        # save slic_mask
        output_name = os.path.join(supervoxel_path,center,center+'_' + mask_path.split('/')[-1].split('.')[0] + '_SVmask.nii.gz')
        sitk.WriteImage(mask_itk, output_name)
        print('{} is Done'.format(output_name.split('/')[-1]))

#TODO
# def resampe():
# def normalization():

# %% [markdown]
# #### Set User Parameters

# %%
# User parameters - path

# data_dir = r'/media/zhenwei/3b5e8580-3829-4c0a-b2fa-ce0cd26a7d93/Data/Breast_MRI/SY'  # specify where your data store
data_dir = r'/media/zhenwei/3b5e8580-3829-4c0a-b2fa-ce0cd26a7d93/Data/Breast_MRI/HN'
code_dir = r'/home/zhenwei/Documents/ProjectCode/image_processing/SVoxel' # as a working directory

# User parameters - sub-vlume
n_segment = 100
center = 'hn'
# center = 'hn'

# User parameters - radiomics
casetable_dir = r'../output/CaseTable'
rf_dir = r'../output/RF'

# --------------------------------------------------------
tmp_volume = os.path.join(code_dir,'tmp_dir','VolumeDir')
tmp_mask = os.path.join(code_dir,'tmp_dir','MaskDir')
out_dir = os.path.join(code_dir,'output')
SVS_dir = os.path.join(out_dir,'SV','SVSplit')
SVSmask_dir = os.path.join(out_dir,'SV','SVSplit','SVmask')
SVSvolume_dir = os.path.join(out_dir,'SV','SVSplit','SVvolume')
SVwhole_dir = os.path.join(out_dir,'SV','SVWhole')

# --------------------------------------------------------
## remove files from temparal directory
if os.path.isdir(tmp_volume):
    shutil.rmtree(tmp_volume)

if os.path.isdir(tmp_mask):
    shutil.rmtree(tmp_mask)
# --------------------------------------------------------
# check if dirs exist
dir_list = [out_dir,tmp_volume,tmp_mask,SVS_dir,SVSmask_dir,SVSvolume_dir,SVwhole_dir,casetable_dir,rf_dir]
for dir in dir_list:
    if not os.path.exists(dir):
        os.makedirs(dir)

# %%
# for users 
# specify image nii dir and mask nii dir

volume_list= glob.glob(os.path.join(data_dir,'pre','volume_hstmp','*'))
mask_list = glob.glob(os.path.join(data_dir,'pre','mask','*'))

volume_list.sort()
mask_list.sort()

# check if they are in the same length
#TODO check id and pre/post
check_dataset(volume_list, mask_list)

# %% [markdown]
# #### Implementation of sub-volume calculation

# %%
# copy files to fixed and temparal dirs for easy process 
for volume, mask in zip(volume_list,mask_list):
    shutil.copy2(volume,os.path.join(code_dir,'tmp_dir','VolumeDir'))
    shutil.copy2(mask,os.path.join(code_dir,'tmp_dir','MaskDir'))

volume_list_new = glob.glob(os.path.join(code_dir,'tmp_dir','VolumeDir','*'))
mask_list_new = glob.glob(os.path.join(code_dir,'tmp_dir','MaskDir','*'))
volume_list_new.sort()
mask_list_new.sort()

# check if they are in the same length
check_dataset(volume_list_new, mask_list_new)
print('Dataset checked!')

# supervoxel calculation by slic, 
supervoxel(volume_list_new, mask_list_new, n_segment,SVwhole_dir,center)
print('Supervoxel Done')

sv_list = mac_os_listdir(os.path.join(SVwhole_dir,center))
sv_list.sort()
sv_list = [os.path.join(SVwhole_dir,center, file) for file in sv_list]
check_dataset(volume_list_new, sv_list)

# supervoxel split for further processing
print('Start SV split processing ...')
for volume_i, mask_j in zip(volume_list_new, sv_list):
    SV_split(volume_i, mask_j, SVS_dir)
print('SV split done')
# Out:
# Dataset checked!
# Start super voxel processing ...
# hn_prcsd_tumor_630755_SVmask.nii.gz is Done
# hn_prcsd_tumor_633342_SVmask.nii.gz is Done
# hn_prcsd_tumor_635536_SVmask.nii.gz is Done
# hn_prcsd_tumor_636017_SVmask.nii.gz is Done
# hn_prcsd_tumor_637937_SVmask.nii.gz is Done
# hn_prcsd_tumor_638552_SVmask.nii.gz is Done
# hn_prcsd_tumor_639805_SVmask.nii.gz is Done
# hn_prcsd_tumor_639980_SVmask.nii.gz is Done
# hn_prcsd_tumor_640531_SVmask.nii.gz is Done
# hn_prcsd_tumor_640879_SVmask.nii.gz is Done
# hn_prcsd_tumor_640905_SVmask.nii.gz is Done
# hn_prcsd_tumor_641637_SVmask.nii.gz is Done
# hn_prcsd_tumor_642986_SVmask.nii.gz is Done
# hn_prcsd_tumor_643289_SVmask.nii.gz is Done
# hn_prcsd_tumor_643436_SVmask.nii.gz is Done
# hn_prcsd_tumor_643982_SVmask.nii.gz is Done
# hn_prcsd_tumor_644164_SVmask.nii.gz is Done
# hn_prcsd_tumor_644272_SVmask.nii.gz is Done
# hn_prcsd_tumor_645010_SVmask.nii.gz is Done
# hn_prcsd_tumor_645654_SVmask.nii.gz is Done
# hn_prcsd_tumor_646021_SVmask.nii.gz is Done
# hn_prcsd_tumor_647037_SVmask.nii.gz is Done
# hn_prcsd_tumor_647459_SVmask.nii.gz is Done
# hn_prcsd_tumor_647620_SVmask.nii.gz is Done
# hn_prcsd_tumor_647659_SVmask.nii.gz is Done
# hn_prcsd_tumor_647878_SVmask.nii.gz is Done
# hn_prcsd_tumor_647919_SVmask.nii.gz is Done
# hn_prcsd_tumor_648134_SVmask.nii.gz is Done
# hn_prcsd_tumor_648401_SVmask.nii.gz is Done
# hn_prcsd_tumor_648729_SVmask.nii.gz is Done
# hn_prcsd_tumor_650415_SVmask.nii.gz is Done
# hn_prcsd_tumor_650605_SVmask.nii.gz is Done
# hn_prcsd_tumor_650757_SVmask.nii.gz is Done
# hn_prcsd_tumor_651041_SVmask.nii.gz is Done
# hn_prcsd_tumor_651748_SVmask.nii.gz is Done
# hn_prcsd_tumor_652133_SVmask.nii.gz is Done
# hn_prcsd_tumor_652618_SVmask.nii.gz is Done
# hn_prcsd_tumor_652736_SVmask.nii.gz is Done
# hn_prcsd_tumor_653141_SVmask.nii.gz is Done
# hn_prcsd_tumor_653439_SVmask.nii.gz is Done
# hn_prcsd_tumor_653998_SVmask.nii.gz is Done
# hn_prcsd_tumor_654382_SVmask.nii.gz is Done
# hn_prcsd_tumor_655437_SVmask.nii.gz is Done
# hn_prcsd_tumor_656555_SVmask.nii.gz is Done
# hn_prcsd_tumor_659962_SVmask.nii.gz is Done
# hn_prcsd_tumor_660096_SVmask.nii.gz is Done
# hn_prcsd_tumor_660286_SVmask.nii.gz is Done
# hn_prcsd_tumor_660550_SVmask.nii.gz is Done
# hn_prcsd_tumor_660635_SVmask.nii.gz is Done
# hn_prcsd_tumor_661121_SVmask.nii.gz is Done
# hn_prcsd_tumor_661734_SVmask.nii.gz is Done
# hn_prcsd_tumor_662403_SVmask.nii.gz is Done
# hn_prcsd_tumor_662924_SVmask.nii.gz is Done
# hn_prcsd_tumor_663906_SVmask.nii.gz is Done
# hn_prcsd_tumor_664066_SVmask.nii.gz is Done
# hn_prcsd_tumor_664067_SVmask.nii.gz is Done
# hn_prcsd_tumor_664160_SVmask.nii.gz is Done
# hn_prcsd_tumor_665941_SVmask.nii.gz is Done
# hn_prcsd_tumor_666521_SVmask.nii.gz is Done
# hn_prcsd_tumor_666969_SVmask.nii.gz is Done
# hn_prcsd_tumor_667566_SVmask.nii.gz is Done
# hn_prcsd_tumor_668645_SVmask.nii.gz is Done
# hn_prcsd_tumor_668791_SVmask.nii.gz is Done
# hn_prcsd_tumor_668802_SVmask.nii.gz is Done
# hn_prcsd_tumor_670164_SVmask.nii.gz is Done
# hn_prcsd_tumor_670172_SVmask.nii.gz is Done
# hn_prcsd_tumor_670553_SVmask.nii.gz is Done
# hn_prcsd_tumor_671106_SVmask.nii.gz is Done
# hn_prcsd_tumor_671300_SVmask.nii.gz is Done
# hn_prcsd_tumor_671547_SVmask.nii.gz is Done
# hn_prcsd_tumor_671964_SVmask.nii.gz is Done
# hn_prcsd_tumor_672199_SVmask.nii.gz is Done
# hn_prcsd_tumor_673192_SVmask.nii.gz is Done
# hn_prcsd_tumor_674632_SVmask.nii.gz is Done
# hn_prcsd_tumor_675929_SVmask.nii.gz is Done
# hn_prcsd_tumor_676249_SVmask.nii.gz is Done
# hn_prcsd_tumor_676966_SVmask.nii.gz is Done
# hn_prcsd_tumor_677964_SVmask.nii.gz is Done
# hn_prcsd_tumor_680100_SVmask.nii.gz is Done
# hn_prcsd_tumor_680757_SVmask.nii.gz is Done
# hn_prcsd_tumor_681368_SVmask.nii.gz is Done
# hn_prcsd_tumor_683166_SVmask.nii.gz is Done
# hn_prcsd_tumor_683718_SVmask.nii.gz is Done
# hn_prcsd_tumor_683822_SVmask.nii.gz is Done
# hn_prcsd_tumor_684239_SVmask.nii.gz is Done
# hn_prcsd_tumor_684788_SVmask.nii.gz is Done
# hn_prcsd_tumor_684802_SVmask.nii.gz is Done
# hn_prcsd_tumor_685498_SVmask.nii.gz is Done
# hn_prcsd_tumor_685666_SVmask.nii.gz is Done
# hn_prcsd_tumor_686080_SVmask.nii.gz is Done
# hn_prcsd_tumor_686105_SVmask.nii.gz is Done
# hn_prcsd_tumor_686266_SVmask.nii.gz is Done
# hn_prcsd_tumor_686476_SVmask.nii.gz is Done
# hn_prcsd_tumor_686683_SVmask.nii.gz is Done
# hn_prcsd_tumor_687018_SVmask.nii.gz is Done
# hn_prcsd_tumor_687346_SVmask.nii.gz is Done
# hn_prcsd_tumor_687737_SVmask.nii.gz is Done
# hn_prcsd_tumor_688729_SVmask.nii.gz is Done
# hn_prcsd_tumor_689262_SVmask.nii.gz is Done
# hn_prcsd_tumor_689326_SVmask.nii.gz is Done
# hn_prcsd_tumor_690966_SVmask.nii.gz is Done
# hn_prcsd_tumor_690969_SVmask.nii.gz is Done
# hn_prcsd_tumor_692734_SVmask.nii.gz is Done
# hn_prcsd_tumor_692817_SVmask.nii.gz is Done
# hn_prcsd_tumor_692870_SVmask.nii.gz is Done
# hn_prcsd_tumor_692891_SVmask.nii.gz is Done
# hn_prcsd_tumor_693027_SVmask.nii.gz is Done
# hn_prcsd_tumor_693159_SVmask.nii.gz is Done
# hn_prcsd_tumor_693842_SVmask.nii.gz is Done
# hn_prcsd_tumor_695785_SVmask.nii.gz is Done
# hn_prcsd_tumor_696631_SVmask.nii.gz is Done
# hn_prcsd_tumor_711623_SVmask.nii.gz is Done
# Supervoxel Done
# Start SV split processing ...
# SV split done

# %% [markdown]
# #### Generate case table for radiomics

# %%
# for radiomics - prepare casetable
image_files = volume_list_new
mask_files = os.listdir(SVSmask_dir)
image_files.sort()
mask_files.sort()

check_dataset(image_files, mask_files)

for i in range(0,len(image_files)):
    img_id = image_files[i].split('/')[-1].split('_')[-2]
    
    SV_files = mac_os_listdir(os.path.join(SVSmask_dir,mask_files[i]))
    SV_files.sort()
    CaseTable = pd.DataFrame()
    for j in range(0,len(SV_files)):
        ptid = pd.Series({'ID':img_id+'_'+SV_files[j].split('.')[-3]})
        Image_path = pd.Series({'Image':image_files[i]})
        Mask_path = pd.Series({'Mask':os.path.join(SVSmask_dir,mask_files[i],SV_files[j])})

        case_id_img = ptid.append(Image_path)
        case_id_img_mask = case_id_img.append(Mask_path)
        CaseTable = pd.concat([CaseTable,case_id_img_mask],axis = 1)

    # generate case table for radiomics calculation, including ID, image and mask path
    CaseTable.T.to_csv(os.path.join(casetable_dir,img_id +'_CaseTable.csv'),index=False)

# %% [markdown]
# #### Implementation of radiomics calculation

# %%
# for radiomics calculation
# recommand to run it on command line
# %run ../script/batchProcessingWithPandas_SV.py
# Out:
# pyradiomics version: v3.0.1
# Loading CSV
# Loading Done
# Patients: 99
# Loading parameter file ../Radiomics_Settings/exampleMR_1mm_SV.yaml
# Enabled input images types: {'Original': {}}
# Enabled features: {'shape': None, 'firstorder': None, 'glcm': ['Autocorrelation', 'JointAverage', 'ClusterProminence', 'ClusterShade', 'ClusterTendency', 'Contrast', 'Correlation', 'DifferenceAverage', 'DifferenceEntropy', 'DifferenceVariance', 'JointEnergy', 'JointEntropy', 'Imc1', 'Imc2', 'Idm', 'Idmn', 'Id', 'Idn', 'InverseVariance', 'MaximumProbability', 'SumEntropy', 'SumSquares'], 'glrlm': None, 'glszm': None, 'gldm': None, 'ngtdm': None}
# Current settings: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': True, 'normalizeScale': 100, 'removeOutliers': None, 'resampledPixelSpacing': [1, 1, 1], 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True, 'binWidth': 5, 'voxelArrayShift': 300}
# (1/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask1.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (2/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask10.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (3/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask11.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (4/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask12.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (5/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask13.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (6/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask14.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (7/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask15.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (8/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask16.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (9/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask17.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (10/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask18.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (11/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask19.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (12/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask2.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (13/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask20.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (14/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask21.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (15/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask22.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (16/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask23.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (17/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask24.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (18/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask25.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (19/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask26.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (20/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask27.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (21/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask28.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (22/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask29.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (23/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask3.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (24/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask30.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (25/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask31.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (26/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask32.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (27/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask33.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (28/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask34.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (29/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask35.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (30/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask36.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (31/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask37.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (32/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask38.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (33/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask39.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (34/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask4.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (35/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask40.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (36/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask41.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (37/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask42.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (38/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask43.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (39/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask44.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (40/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask45.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (41/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask46.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (42/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask47.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (43/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask48.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (44/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask49.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (45/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask5.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (46/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask50.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (47/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask51.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (48/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask52.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (49/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask53.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (50/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask54.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (51/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask55.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (52/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask56.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (53/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask57.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (54/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask58.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (55/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask59.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (56/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask6.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (57/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask60.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (58/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask61.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (59/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask62.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (60/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask63.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (61/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask64.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (62/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask65.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (63/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask66.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (64/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask67.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (65/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask68.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (66/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask69.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (67/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask7.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (68/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask70.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (69/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask71.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (70/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask72.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (71/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask73.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (72/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask74.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (73/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask75.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (74/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask76.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (75/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10099473.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10099473/sy_prcsd_tumor_10099473_SVmask77.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# ...
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (76/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10292892.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10292892/sy_prcsd_tumor_10292892_SVmask77.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (77/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10292892.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10292892/sy_prcsd_tumor_10292892_SVmask78.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (78/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10292892.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10292892/sy_prcsd_tumor_10292892_SVmask79.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (79/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10292892.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10292892/sy_prcsd_tumor_10292892_SVmask8.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (80/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10292892.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10292892/sy_prcsd_tumor_10292892_SVmask80.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (81/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10292892.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10292892/sy_prcsd_tumor_10292892_SVmask81.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (82/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10292892.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10292892/sy_prcsd_tumor_10292892_SVmask82.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (83/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10292892.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10292892/sy_prcsd_tumor_10292892_SVmask83.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (84/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10292892.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10292892/sy_prcsd_tumor_10292892_SVmask84.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (85/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10292892.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10292892/sy_prcsd_tumor_10292892_SVmask85.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (86/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10292892.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10292892/sy_prcsd_tumor_10292892_SVmask86.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (87/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10292892.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10292892/sy_prcsd_tumor_10292892_SVmask87.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (88/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10292892.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10292892/sy_prcsd_tumor_10292892_SVmask88.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (89/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10292892.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10292892/sy_prcsd_tumor_10292892_SVmask89.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (90/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10292892.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10292892/sy_prcsd_tumor_10292892_SVmask9.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (91/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10292892.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10292892/sy_prcsd_tumor_10292892_SVmask90.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (92/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10292892.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10292892/sy_prcsd_tumor_10292892_SVmask91.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (93/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10292892.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10292892/sy_prcsd_tumor_10292892_SVmask92.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (94/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10292892.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10292892/sy_prcsd_tumor_10292892_SVmask93.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (95/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10292892.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10292892/sy_prcsd_tumor_10292892_SVmask94.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (96/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10292892.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10292892/sy_prcsd_tumor_10292892_SVmask95.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (97/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10292892.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10292892/sy_prcsd_tumor_10292892_SVmask96.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (98/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10292892.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10292892/sy_prcsd_tumor_10292892_SVmask97.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (99/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10292892.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10292892/sy_prcsd_tumor_10292892_SVmask98.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# (100/3) Processing Patient (Image: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/tmp_dir/VolumeDir/pre_C2_prcsd_volume_10292892.nii.gz, Mask: /home/zhenwei/Documents/ProjectCode/image_processing/SVoxel/output/SV/SVSplit/SVmask/10292892/sy_prcsd_tumor_10292892_SVmask99.nii.gz)
# Calculating features with label: 1
# Loading image and mask
# New spacing equal to original image spacing, just resampling the mask
# Computing shape
# Adding image type "Original" with custom settings: {}
# Calculating features for original image
# Computing firstorder
# Computing glcm
# Computing glrlm
# Computing glszm
# Computing gldm
# Computing ngtdm
# Extraction complete, writing CSV
# CSV writing complete
